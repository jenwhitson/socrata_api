# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image
import folium
import pickle
from sodapy import Socrata
from datetime import datetime


# %matplotlib inline

# %%
endpoint = "https://data.nashville.gov/resource/7qhx-rexh.json"

# %%
hub = []
for value in range(13):
    params = {'$limit': 50000, '$offset': 50000 * (value)}
    response = requests.get(endpoint, params = params)
    res = response.json()
    hub.extend(res)
    print(response)
    print(value)
# Out:
# <Response [200]>
# 1
# <Response [200]>
# 2
# <Response [200]>
# 3
# <Response [200]>
# 4
# <Response [200]>
# 5
# <Response [200]>
# 6
# <Response [200]>
# 7
# <Response [200]>
# 8
# <Response [200]>
# 9
# <Response [200]>
# 10
# <Response [200]>
# 11
# <Response [200]>
# 12
# <Response [200]>
# 13

# %%
hub311 = pd.DataFrame(hub)
hub311.head()
# Out:
#   case_number  status                            case_request  \
# 0      198180  Closed  Resolved by hubNashville on First Call
# 1      197727  Closed  Resolved by hubNashville on First Call
# 2      197987  Closed  Resolved by hubNashville on First Call
# 3      198062  Closed  Resolved by hubNashville on First Call
# 4      197917  Closed  Resolved by hubNashville on First Call
#
#                           case_subrequest  \
# 0  Resolved by hubNashville on First Call
# 1  Resolved by hubNashville on First Call
# 2  Resolved by hubNashville on First Call
# 3  Resolved by hubNashville on First Call
# 4  Resolved by hubNashville on First Call
#
#                     additional_subrequest         date_time_opened  \
# 0  Resolved by hubNashville on First Call  2019-06-11T18:15:39.000
# 1  Resolved by hubNashville on First Call  2019-06-10T21:24:14.000
# 2  Resolved by hubNashville on First Call  2019-06-11T15:06:56.000
# ...

# %%
hub311.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627061 entries, 0 to 627060
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   case_number                  627061 non-null  object
#  1   status                       627061 non-null  object
#  2   case_request                 626712 non-null  object
#  3   case_subrequest              623806 non-null  object
#  4   additional_subrequest        617121 non-null  object
#  5   date_time_opened             627061 non-null  object
#  6   date_time_closed             614338 non-null  object
#  7   case_origin                  627061 non-null  object
#  8   state_issue                  627061 non-null  object
#  9   closed_when_created          627061 non-null  object
#  10  incident_address             432597 non-null  object
#  11  incident_city                425122 non-null  object
# ...

# %%
hubsub = hub311[['case_number', 'date_time_opened', 'date_time_closed', 'incident_address', 'case_origin', 'case_request']]

# %%
hubsub
# Out:
#        case_number         date_time_opened         date_time_closed  \
# 0           198180  2019-06-11T18:15:39.000  2019-06-11T18:15:39.000
# 1           197727  2019-06-10T21:24:14.000  2019-06-10T21:24:14.000
# 2           197987  2019-06-11T15:06:56.000  2019-06-11T15:06:56.000
# 3           198062  2019-06-11T16:03:54.000  2019-06-11T16:03:54.000
# 4           197917  2019-06-11T13:56:36.000  2019-06-11T13:56:36.000
# ...            ...                      ...                      ...
# 627056      621759  2021-03-12T19:44:29.000                      NaN
# 627057      621517  2021-03-12T17:11:20.000                      NaN
# 627058      620542  2021-03-11T23:16:00.000                      NaN
# 627059      619146  2021-03-10T23:01:48.000                      NaN
# 627060      620010  2021-03-11T18:41:21.000                      NaN
#
#               incident_address             case_origin  \
# 0                          NaN                   Phone
# ...

# %%
hubsub['case_request'].value_counts()
# Out:
# Trash, Recycling & Litter                          203222
# Resolved by hubNashville on First Call             193895
# Streets, Roads & Sidewalks                         114363
# Property Violations                                 32247
# Public Safety                                       27821
# COVID-19                                            22753
# Other                                               11030
# Electric & Water General                             7376
# Transit                                              5745
# Hands On Volunteers                                  2639
# Permits                                              1827
# Parks                                                1630
# Police Chief Search                                  1112
# Planning & Zoning                                     323
# 2nd Avenue Explosion Information and Assistance       284
# Storm Relief                                          174
# ...
